# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('./ISL Finger Dataset/1/1.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (256, 256, 3)

# %%
imgplot = plt.imshow(img)
plt.show()

# %%
from PIL import Image
img = Image.open('./ISL Finger Dataset/1/1.jpg')
img_resized = img.resize((100, 100))
img_resized.save('1_resized.jpg')

# %%
img_res = mpimg.imread('1_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (100, 100, 3)
